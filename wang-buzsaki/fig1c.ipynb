# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %%
! cargo run --example fig1c > fig1c.csv
# Out:
#     Finished dev [unoptimized + debuginfo] target(s) in 0.12s
#      Running `target\debug\examples\fig1c.exe`

# %%
df = pd.read_csv("fig1c.csv", index_col=0)
df.columns
# Out:
# Index(['V_pre(mV)', 'I_app(uA/cm2)', 'V_post(mV)', 'I_syn(uA/cm2)'], dtype='object')

# %%
df["V_pre(mV)"].plot()
plt.xlim([0, 150])
plt.ylim([-80, 40])
plt.ylabel("V_pre")
plt.title("fig.1C 1st")
plt.savefig("fig1C1.png")

# %%
df["I_app(uA/cm2)"].plot()
plt.xlim([0, 150])
plt.ylim([-0.1, 2.1])
plt.ylabel("I_app")
plt.title("fig.1C 2nd")
plt.savefig("fig1C2.png")

# %%
df["V_post(mV)"].plot()
plt.xlim([0, 150])
plt.ylim([-68, -64])
plt.ylabel("V_post")
plt.title("fig.1C 3rd")
plt.savefig("fig1C3.png")

# %%
df["I_syn(uA/cm2)"].plot()
plt.xlim([0, 150])
plt.ylim([0, 1])
plt.ylabel("I_syn")
plt.title("fig.1C 4th")
plt.savefig("fig1C4.png")
